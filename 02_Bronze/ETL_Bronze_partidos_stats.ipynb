# %%
# %sql
COPY INTO laliga.bronze.partidos_stats
FROM "/Volumes/laliga/bronze/volume/partidos_raw_san-lor.parquet"
FILEFORMAT = PARQUET
COPY_OPTIONS ('mergeSchema' = 'true');

# %%
# %sql

SELECT * FROM laliga.bronze.partidos_stats
