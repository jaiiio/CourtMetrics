# %%
# %sql
COPY INTO laliga.bronze.fixture
FROM "/Volumes/laliga/bronze/volume/fixture.parquet"
FILEFORMAT = PARQUET
COPY_OPTIONS ('mergeSchema' = 'true');

# %%
# %sql

SELECT * FROM laliga.bronze.fixture
