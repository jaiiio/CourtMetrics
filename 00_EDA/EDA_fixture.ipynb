# %%
# %sql

DESCRIBE laliga.bronze.fixture

# %%
# %sql

SELECT * FROM laliga.bronze.fixture

# %%
# %sql
SELECT url, SPLIT(url, '/') FROM laliga.bronze.fixture LIMIT 5

# %%
# %sql
SELECT COUNT(*) FROM laliga.bronze.fixture

# %%
# %sql
SELECT 
  id_partido,
  COUNT(*) as amount
FROM laliga.bronze.fixture
GROUP BY id_partido
HAVING COUNT(*) > 1

# %%
# %sql
SELECT MIN(date), MAX(date) FROM laliga.bronze.fixture

# %%
# %sql

SELECT
  COUNT(*) - COUNT(id_partido),
  COUNT(*) - COUNT(url),
  COUNT(*) - COUNT(rival),
  COUNT(*) - COUNT(date)
FROM laliga.bronze.fixture
