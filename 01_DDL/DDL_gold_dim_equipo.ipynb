# %%
# %sql

DROP TABLE IF EXISTS laliga.gold.dim_equipo;

CREATE TABLE IF NOT EXISTS laliga.gold.dim_equipo(
  IdClub STRING, 
  IdEquipo STRING,
  NombreEquipo STRING, 
  _source_table STRING,
  _processing_timestamp TIMESTAMP,
  CONSTRAINT pk_dim_equipo PRIMARY KEY (IdEquipo)
)
USING DELTA
