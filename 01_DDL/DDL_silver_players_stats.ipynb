# %%
# %sql
DROP TABLE IF EXISTS laliga.silver.players_stats;

CREATE TABLE IF NOT EXISTS laliga.silver.players_stats(
  id_partido STRING,
  IdJugador STRING,
  IdClub STRING,
  IdEquipo STRING,
  --Dorsal STRING,
  Apellido STRING, -- columna nombrecompleto
  Nombre STRING,
  CincoInicial INT,
  TiempoJuego DOUBLE,
  Puntos BIGINT,
  --TirosDos.*,
  tiros_2p_aciertos BIGINT,
  tiros_2p_fallados BIGINT,
  tiros_2p_totales BIGINT,
  tiros_2p_pctg BIGINT,
  --TirosTres.*,
  tiros_3p_aciertos BIGINT,
  tiros_3p_fallados BIGINT,
  tiros_3p_totales BIGINT,
  tiros_3p_pctg BIGINT,
  --TirosLibres.*,
  libres_aciertos BIGINT,
  libres_fallados BIGINT,
  libres_totales BIGINT,
  libres_pctg BIGINT,
  ReboteDefensivo BIGINT,
  ReboteOfensivo BIGINT,
  RebotesTotales BIGINT,
  Asistencias BIGINT,
  Recuperaciones BIGINT,
  Perdidas BIGINT,
  TaponCometido BIGINT,
  TaponRecibido BIGINT,
  FaltaCometida BIGINT,
  FaltaRecibida BIGINT,
  _source_table STRING,
  _processing_timestamp TIMESTAMP
)
USING DELTA
