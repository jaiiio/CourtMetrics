# %%
# %sql

DROP TABLE IF EXISTS laliga.gold.dim_jugadores;

CREATE TABLE IF NOT EXISTS laliga.gold.dim_jugadores(
  IdJugador STRING NOT NULL,
  IdClub STRING,
  IdEquipo STRING,
  Dorsal STRING,
  Apellido STRING,
  Nombre STRING,
  _source_table STRING,
  _processing_timestamp TIMESTAMP,
  CONSTRAINT pk_dim_jugadores PRIMARY KEY (IdJugador)
)
USING DELTA
