# %%
# %sql
CREATE CATALOG IF NOT EXISTS laliga

# %%
# %sql

USE CATALOG laliga

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS laliga.bronze

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS laliga.silver

# %%
# %sql

CREATE SCHEMA IF NOT EXISTS laliga.gold

# %%
# %sql
SHOW SCHEMAS

# %%
# %sql

CREATE VOLUME IF NOT EXISTS laliga.bronze.volume
