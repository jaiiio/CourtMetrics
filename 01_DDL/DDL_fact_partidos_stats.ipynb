# %%
# %sql

DROP TABLE IF EXISTS laliga.gold.fact_partidos_stats;

CREATE TABLE IF NOT EXISTS laliga.gold.fact_partidos_stats(
  id_partido STRING, 
  IdEquipo STRING, 
  puntos_favor INT,
  puntos_contra INT,
  tiros_campo_totales INT,
  tiros_libres_totales INT,
  rebotes_ofensivos INT,
  perdidas_partido INT,
  posesiones INT,
  ortg DOUBLE,
  drtg DOUBLE,
  net_rating DOUBLE,
  _source_table STRING,
  _processing_timestamp STRING,
  CONSTRAINT pk_id_partido PRIMARY KEY (id_partido, IdEquipo)
)
