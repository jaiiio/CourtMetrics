# %%
# %sql
DROP TABLE IF EXISTS laliga.gold.dim_partidos;

CREATE TABLE IF NOT EXISTS laliga.gold.dim_partidos(
  id_partido STRING,
  url STRING,
  local_team STRING,
  visit_team STRING,
  match_date timestamp_ntz,
  _source_table STRING,
  _processing_timestamp TIMESTAMP 
)
USING DELTA
